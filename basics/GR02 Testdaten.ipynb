# %% [markdown]
# # Testdaten

# %% [markdown]
# Zur Entwicklung und Demonstration der verschiedenen Verfahren werden Testdaten benötigt.

# %% [markdown]
# ## Erzeugung von Testdaten
#
# Scikit-learn stellt zur Erzeugung künstlicher Testdaten eine reihe von Funktionen zur Verfügung, die wir hier vorstellen wollen. Zusätzlich erzeugen wir die für dieses Kapitel notwendigen Testdaten und speichern sie für die spätere Verwendung ab.

# %%
import numpy as np
import matplotlib.pyplot as plt

import sklearn.datasets as ds 
import pandas as pd

# %% [markdown]
# ### Blobs

# %%
X, y = ds.make_blobs(n_samples = 100, n_features = 2, centers = 3, random_state = 1)

plt.scatter(X[:,0], X[:, 1],c = y)
pass
